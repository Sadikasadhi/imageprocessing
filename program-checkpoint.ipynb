# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\user\anaconda1\lib\site-packages (from opencv-python) (1.20.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
img=cv2.imread('rose5.jpg',0)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.image as mping
import matplotlib.pyplot as plt
img=mping.imread('rose2.jpg')
plt.imshow(img)

# %%
import cv2
from PIL import Image
img=Image.open('leaf1.jpg')
img=img.rotate(180)
img.show()
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from PIL import ImageColor
img1=ImageColor.getrgb("yellow")
print(img1)
img2=ImageColor.getrgb("red")
print(img2)
img1=ImageColor.getrgb("pink")
print(img3)
# Out:
# (255, 255, 0)
# (255, 0, 0)
# (255, 192, 203)

# %%
from PIL import Image
img=Image.new('RGB',(200,400),(255,192,203))
img.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('rose2.jpg')
plt.imshow(img)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.show()
img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)
plt.show()

# %%
from PIL import Image
image=Image.open('rose.jpg')
print("Filename:",image.filename)
print("Format:",image.format)
print("Mode:",image.mode)
print("Size:",image.size)
print("Width:",image.width)
print("Height:",image.height)
image.close()
# Out:
# Filename: rose4.jpg
# Format: JPEG
# Mode: RGB
# Size: (2448, 3264)
# Width: 2448
# Height: 3264
